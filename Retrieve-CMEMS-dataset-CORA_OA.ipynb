# %% [markdown]
# # Retrieve a CMEMS dataset - CORA OA

# %% [markdown]
# ### 0. setup environment

# %% [markdown]
# #### Requirements

# %%
packages = ['pystac_client',
            'copernicusmarine',
            'xarray',
            'requests',
            'aiohttp',
            'copernicusmarine',
            'cartopy',
           'geopandas']

# %% [markdown]
# #### Install packages

# %%
for package in packages:
    # !pip install {package} > /dev/null 2>&1

# %% [markdown]
# #### Load packages

# %%
for package in packages:
    exec(f'import {package}')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import os
import geopandas
import cartopy.crs as ccrs
import json
import ast
from copernicusmarine.core_functions import custom_open_zarr
from shapely.geometry import Point, box, Polygon, shape
import geopandas as gpd
from shapely import wkt

# %% [markdown]
# <br>
#
# ### 1. Open the STAC catalog
# Using pystac client you can connect to the STAC.

# %%
url = 'https://catalog.dive.edito.eu'
client = pystac_client.Client.open(url)
print(client)
# Out:
# <Client id=root>

# %% [markdown]
# <br>
#
# ### 2. Load collections
# One property of the STAC is collections, its a good way to explore the available datasets.

# %%
collections = list(client.get_collections())

# %% [markdown]
# Lets see how many collections there are:

# %%
print(f"number of collections: {len(collections)}")
# Out:
# number of collections: 445

# %% [markdown]
# <br>
#
# ### 3. Query collections
# We will loop over the collections and filter a variable defined in CMEMS such as: Mass concentration of chlorophyll a in sea water. Notice that we need to add underscores as spaces are not accepted.
# #### 3.1 Filter on variable

# %%
variable1 = "sea_water_temperature"

# %% [markdown]
# If you use one of the easiest variables to obtain from the product website for CORA OA in-situ data (https://data.marine.copernicus.eu/product/INSITU_GLO_PHY_TS_OA_MY_013_052/description). This data only have sea water temperature and sea water salinity available.
#
# For STAC search purposes, it is easier to search for sea_water_temperature as a variable.

# %%
for collection in collections:
    if variable1 in collection.id:
        print(collection.id)
# Out:
# climate_forecast-sea_water_temperature

# %% [markdown]
# #### 3.2 Retrieve products
# Get all the products from these collections.
#
# <i> This is where I have run into issues because I am not sure how to introduce a start_datetime and end_datetime in the internal item.Item search. </i>

# %%
products = []

for collection in collections:
    if variable1 in collection.id:
        for i, item in enumerate(collection.get_items()):
            products.append(item)
# Out:
# ---------------------------------------------------------------------------
# STACError                                 Traceback (most recent call last)
# Cell In[68], line 5
#       3 for collection in collections:
#       4     if variable1 in collection.id:
# ----> 5         for i, item in enumerate(collection.get_items()):
#       6             products.append(item)
#
# File /opt/conda/lib/python3.12/site-packages/pystac_client/collection_client.py:147, in CollectionClient.get_items(self, recursive, *ids)
#     137     url = root._search_href() if ids else self._items_href()
#     139     search = ItemSearch(
#     140         url=url,
#     141         method="GET",
#    (...)    145         modifier=self.modifier,
#     146     )
# --> 147     yield from search.items()
#     148 else:
#     149     root._warn_about_fallback("ITEM_SEARCH")
#
# File /opt/conda/lib/python3.12/site-packages/pystac_client/item_search.py:787, in ItemSearch.items(self)
#     779 """Iterator that yields :class:`pystac.Item` instances for each item matching
#     780 the given search parameters.
#     781
#     782 Yields:
#     783     Item : each Item matching the search criteria
#     784 """
#     785 for item in self.items_as_dicts():
#     786     # already signed in items_as_dicts
# --> 787     yield Item.from_dict(item, root=self.client, preserve_dict=False)
#
# File /opt/conda/lib/python3.12/site-packages/pystac/item.py:462, in Item.from_dict(cls, d, href, root, migrate, preserve_dict)
#     455 # get all the fields that are not passed through, parsed, or excluded
#     456 extra_fields = {
#     457     k: v
#     458     for k, v in d.items()
#     459     if k not in [*pass_through_fields, *parse_fields, *exclude_fields]
#     460 }
# --> 462 item = cls(
#     463     **{k: d.get(k) for k in pass_through_fields},  # type: ignore
#     464     datetime=datetime,
#     465     properties=properties,
#     466     extra_fields=extra_fields,
#     467     href=href,
#     468     assets={k: Asset.from_dict(v) for k, v in assets.items()},
#     469 )
#     471 for link in links:
#     472     if href is None or link.get("rel", None) != RelType.SELF:
#
# File /opt/conda/lib/python3.12/site-packages/pystac/item.py:149, in Item.__init__(self, id, geometry, bbox, datetime, properties, start_datetime, end_datetime, stac_extensions, href, collection, extra_fields, assets)
#     147 if datetime is None:
#     148     if "start_datetime" not in properties or "end_datetime" not in properties:
# --> 149         raise STACError(
#     150             "Invalid Item: If datetime is None, "
#     151             "a start_datetime and end_datetime "
#     152             "must be supplied."
#     153         )
#     154     self.datetime = None
#     155 else:
#
# STACError: Invalid Item: If datetime is None, a start_datetime and end_datetime must be supplied.

# %% [markdown]
# Lets see how many products this is.

# %%
print(f"number of products: {len(products)}")
# Out:
# number of products: 148

# %% [markdown]
# #### 3.3 Filter the products

# %%
product_id = "INSITU_GLO_PHY_TS_OA_MY_013_052"

# %%
for collection in collections:
    if variable1 in collection.id:
        for i, item in enumerate(collection.get_items()):
            for asset_key, asset in item.assets.items():
                if product_id in asset.href:
                    print(i, asset.href)
# Out:
# ---------------------------------------------------------------------------
# STACError                                 Traceback (most recent call last)
# Cell In[54], line 3
#       1 for collection in collections:
#       2     if variable1 in collection.id:
# ----> 3         for i, item in enumerate(collection.get_items()):
#       4             for asset_key, asset in item.assets.items():
#       5                 if product_id in asset.href:
#
# File /opt/conda/lib/python3.12/site-packages/pystac_client/collection_client.py:147, in CollectionClient.get_items(self, recursive, *ids)
#     137     url = root._search_href() if ids else self._items_href()
#     139     search = ItemSearch(
#     140         url=url,
#     141         method="GET",
#    (...)    145         modifier=self.modifier,
#     146     )
# --> 147     yield from search.items()
#     148 else:
#     149     root._warn_about_fallback("ITEM_SEARCH")
#
# File /opt/conda/lib/python3.12/site-packages/pystac_client/item_search.py:787, in ItemSearch.items(self)
#     779 """Iterator that yields :class:`pystac.Item` instances for each item matching
#     780 the given search parameters.
#     781
#     782 Yields:
#     783     Item : each Item matching the search criteria
#     784 """
#     785 for item in self.items_as_dicts():
#     786     # already signed in items_as_dicts
# --> 787     yield Item.from_dict(item, root=self.client, preserve_dict=False)
#
# File /opt/conda/lib/python3.12/site-packages/pystac/item.py:462, in Item.from_dict(cls, d, href, root, migrate, preserve_dict)
#     455 # get all the fields that are not passed through, parsed, or excluded
#     456 extra_fields = {
#     457     k: v
#     458     for k, v in d.items()
#     459     if k not in [*pass_through_fields, *parse_fields, *exclude_fields]
#     460 }
# --> 462 item = cls(
#     463     **{k: d.get(k) for k in pass_through_fields},  # type: ignore
#     464     datetime=datetime,
#     465     properties=properties,
#     466     extra_fields=extra_fields,
#     467     href=href,
#     468     assets={k: Asset.from_dict(v) for k, v in assets.items()},
#     469 )
#     471 for link in links:
#     472     if href is None or link.get("rel", None) != RelType.SELF:
#
# File /opt/conda/lib/python3.12/site-packages/pystac/item.py:149, in Item.__init__(self, id, geometry, bbox, datetime, properties, start_datetime, end_datetime, stac_extensions, href, collection, extra_fields, assets)
#     147 if datetime is None:
#     148     if "start_datetime" not in properties or "end_datetime" not in properties:
# --> 149         raise STACError(
#     150             "Invalid Item: If datetime is None, "
#     151             "a start_datetime and end_datetime "
#     152             "must be supplied."
#     153         )
#     154     self.datetime = None
#     155 else:
#
# STACError: Invalid Item: If datetime is None, a start_datetime and end_datetime must be supplied.
